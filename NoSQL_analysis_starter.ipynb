# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the collection to a variable
establishments = db['establishments']
establishments
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Total number of documents in the result: {count}")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# Total number of documents in the result: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65038b8adfe2eaf6c7c336e2'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  65038b8adfe2eaf6c7c336e2   110681                  0
# 1  65038b8adfe2eaf6c7c33a65   612039                  0
# 2  65038b8adfe2eaf6c7c33d71   730933                  0
# 3  65038b8adfe2eaf6c7c33f59   172735                  0
# 4  65038b8adfe2eaf6c7c33f68   172953                  0
# 5  65038b8adfe2eaf6c7c3490a   512854                  0
# 6  65038b8adfe2eaf6c7c34b29  1537089                  0
# 7  65038b8bdfe2eaf6c7c36055   155648                  0
# 8  65038b8bdfe2eaf6c7c3649b  1012883                  0
# 9  65038b8bdfe2eaf6c7c36cb0   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_B = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte':'4'}}

# Use count_documents to display the number of documents in the result
count_B = establishments.count_documents(query_B)
print(f"The number of establishments in London with a Rating Value greater than or equal to 4 is: {count_B}")

# Display the first document in the results using pprint
pprint(establishments.find_one(query_B))
# Out:
# The number of establishments in London with a Rating Value greater than or equal to 4 is: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65038b8adfe2eaf6c7c350f7'),
# ...

# %%
# Convert the result to a Pandas DataFrame
df_B = pd.DataFrame(establishments.find(query_B))

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame: ", len(df_B))

# Display the first 10 rows of the DataFrame
df_B.head(10)
# Out:
# Number of rows in the DataFrame:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  65038b8adfe2eaf6c7c350f7   621707                  0
# 1  65038b8bdfe2eaf6c7c35424  1130836                  0
# 2  65038b8bdfe2eaf6c7c35f73   293783                  0
# 3  65038b8bdfe2eaf6c7c36d71  1315095                  0
# 4  65038b8bdfe2eaf6c7c36d72   294474                  0
# 5  65038b8bdfe2eaf6c7c3747a   294900                  0
# 6  65038b8cdfe2eaf6c7c39583   293756                  0
# 7  65038b8cdfe2eaf6c7c39950   878523                  0
# 8  65038b8cdfe2eaf6c7c3996a   293772                  0
# 9  65038b8cdfe2eaf6c7c3996b   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query_C = {'RatingValue':'5', 'geocode.latitude': {'$lte':(latitude+degree_search),
                                                   '$gte': (latitude - degree_search)}}
sort =  [('scores.Hygiene', 1)]

# Print the results
for result in establishments.find(query_C).sort(sort).limit(5):
    pprint(result)
# Out:
# {'AddressLine1': 'The Oak',
#  'AddressLine2': 'Lodge Lane',
#  'AddressLine3': 'Grays',
#  'AddressLine4': 'Essex',
#  'BusinessName': 'The Oak At Sockets Heath',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4638.029750999956,
#  'FHRSID': 390727,
#  'LocalAuthorityBusinessID': '15410/2003/2/000',
#  'LocalAuthorityCode': '894',
#  'LocalAuthorityEmailAddress': 'foodsafety@thurrock.gov.uk',
#  'LocalAuthorityName': 'Thurrock',
#  'LocalAuthorityWebSite': 'http://www.thurrock.gov.uk/food',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM17 5RZ',
#  'RatingDate': '2022-07-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65038b8bdfe2eaf6c7c36f91'),
#  'geocode': {'latitude': 51.488892, 'longitude': 0.338999},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/390727',
#             'rel': 'self'}],
# ...

# %%
# Convert result to Pandas DataFrame
pd.DataFrame(establishments.find(query_C).sort(sort).limit(5))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65038b8bdfe2eaf6c7c36f91   390727                  0
# 1  65038b8bdfe2eaf6c7c3773c  1502433                  0
# 2  65038b8bdfe2eaf6c7c373ab  1400430                  0
# 3  65038b8bdfe2eaf6c7c36f71  1385053                  0
# 4  65038b8bdfe2eaf6c7c366e5   390400                  0
#
#   LocalAuthorityBusinessID              BusinessName             BusinessType  \
# 0         15410/2003/2/000  The Oak At Sockets Heath        Pub/bar/nightclub
# 1              22/00112/CP                Essex Chef   Takeaway/sandwich shop
# 2              21/00171/CP                   Bourgee  Restaurant/Cafe/Canteen
# 3              21/00149/CP                Macchiatos  Restaurant/Cafe/Canteen
# 4              09/00040/CP      Nancy's Sandwich Bar  Restaurant/Cafe/Canteen
#
#    BusinessTypeID          AddressLine1            AddressLine2  \
# 0            7843               The Oak              Lodge Lane
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match={'$match':{'scores.Hygiene': 0}}
group={'$group':{'_id':'$LocalAuthorityName', 'count':{'$sum': 1}}}
sort={'$sort':{'count':-1}}

pipeline = [match, group, sort]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"The number of documents in the result is: {len(results)}.")

# Print the first 10 results
pprint(results[0:10])
# Out:
# The number of documents in the result is: 55.
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df_C = pd.DataFrame(results)
                    
# Display the number of rows in the DataFrame
print(f"The number of rows in the dataframe is: {len(df_C)}.")
                    
# Display the first 10 rows of the DataFrame
df_C.head(10)
# Out:
# The number of rows in the dataframe is: 55.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
